// %% [markdown]
// ---
// layout: post
// toc: true
// title: Homework Blog
// courses: {csa: {week: 6}}
// type: ccc
// authors: Bella
// permalink: /csa/Homework
// ---

// %% [markdown]
// ## Introduction
//
// This is my homework blog for the CSA team teach. I aim have a basic understanding of Java before diving into Spring-Boot applications, so I've built some cool side projects to help me learn an understand the concepts covered in CB, in addition to popcorn hacks.
//
// All homework can be found in blogs for reference.

// %% [markdown]
// ## Checklist
//
// | **Assignment**                  | **Points**    | **Grade**  | **Evidence**                                                                                                                |
// |----------------------------------|---------------|------------|-----------------------------------------------------------------------------------------------------------------------------|
// | Pull Request (Integration)       | 2             | 1.8        | ![Screenshot](https://github.com/user-attachments/assets/33cb7c0f-109c-4bc0-bd91-28bf3d1a99fa)                              |
// | Relevancy Checklist (Peer)       | 2             |            | Below (Peer Grading Comment)                                                                                                |
// | Lesson (Group)                   | 1             | 0.92       | ![Screenshot](https://github.com/user-attachments/assets/a4666406-75a7-4f4d-bc60-8d416f475a95)                              |
// | Homework, Popcorn Hacks          | 1 x 8         | 5.43 (only 6 graded) | [Google Spreadsheet](https://docs.google.com/spreadsheets/d/1sGQtZm9GI2Rze5F7Eh_P1CMNO8Fyag4bCtOT0ddARmc/edit?gid=0#gid=0)   |
// | Individual Contribution          | 1             |            | ![Screenshot](https://github.com/user-attachments/assets/c95c52fb-da1b-4154-9e52-b5bbe5d120f4)                              |
// | Personal Notebooks / Blogs       | 1             |            | [Personal Notebooks and Blogs](https://ikan2025.github.io/bella_2025/csa)                                                   |
// | **Total**                        | **12**        |            |                                                                                                                             |
//
//
//
//
//
//
//
// ## Skill Assessment
//
// | **Skill**                  | **Points**    | **Grade**  | **Evidence**                                                                                                                |
// |----------------------------|---------------|------------|-----------------------------------------------------------------------------------------------------------------------------|
// | Work Habits (Analytics)     | 1             |            | ![Screenshot](https://github.com/user-attachments/assets/00650a90-cfc3-4116-8023-41cb20257c55)                              |
// | Team Planning (Issue)       | 1             |            | [GitHub Issue](https://github.com/iKAN2025/CSATri1Group/issues/2)                                                           |
// | Presentation Memories       | 1             |            | ![Screenshot](https://github.com/user-attachments/assets/d240deac-cac1-46c7-8dca-1ffaa2c9ea96)                              |
// | Grading and Feedback        | 1             |            | [Google Spreadsheet](https://docs.google.com/spreadsheets/d/1nTRXNkxFtu1Vpn7Qgue9Q6EtaaRdjQPofKh8DRwF1ks/edit?gid=711507468) |
// | Beyond Perfunctory          | 1             |            | ![Screenshot](https://github.com/user-attachments/assets/36c6d1b8-2388-4398-8991-ba60122d5697)                              |
// | **Total**                   | **5**         |            |                                                                                                                             |

// %% [markdown]
// ## [Peer Grading](https://github.com/iKAN2025/bella_2025/issues/15)
//
// How I did, according to my peers in PD 1.

// %% [markdown]
// ## Bouncing Balls Project
//
// <img width="1217" alt="Screenshot 2024-10-10 at 8 18 49 PM" src="https://github.com/user-attachments/assets/56975fcb-65d4-470e-b42b-b52200d0deaa">
//
//
//
//
//
// [Runtime](https://replit.com/@dnchemtutors/Bouncing-Balls)
//
// Over the past few weeks, I've seen a lot of Pygame and other code libraries with graphics. So I decided to create a project that uses concepts from Unit 5 (Writing Class), Unit 6 (Arrays), Unit 3 (Boolean If) Unit 2(Using Objects) with bouncing balls.
//
//
//
// [Resource](https://www.geeksforgeeks.org/what-is-java-awt-graphics/)

// %% [markdown]
// ## Unit 8 - 2D Arrays Lesson
//
// For 2d arrays, I wanted to simulate a create a  3*3 cube with multiple 2d arrays. This is also kind of includes concepts from unit 4 iteration, usinga nestedloop of3 to fill in 3*3*3 = 27 slots!

// %%
public class Cube2DArray {

    public static void main(String[] args) {
        // declare size of the cube
        int size = 3;
        int[][][] cube = new int[size][size][size];

        // 
        for (int z = 0; z < size; z++) {
            for (int y = 0; y < size; y++) {
                for (int x = 0; x < size; x++) {
                    cube[z][y][x] = 2*x + 3*y + 5*z;  // Example value for each cell
                }
            }
        }

        // Print the cube, layer by layer
        for (int z = 0; z < size; z++) {
            System.out.println("Layer " + z + ":");
            print2DArray(cube[z]);
            System.out.println();  // Blank line between layers
        }
    }

    // Method to print a 2D array (a single layer of the cube)
    public static void print2DArray(int[][] layer) {
        for (int[] row : layer) {
            for (int val : row) {
                System.out.print(val + " ");
            }
            System.out.println();
        }
    }
}


Cube2DArray.main(null)
// Out:
// Layer 0:
// 0 2 4
// 3 5 7
// 6 8 10
//
// Layer 1:
// 5 7 9
// 8 10 12
// 11 13 15
//
// Layer 2:
// 10 12 14
// 13 15 17
// 16 18 20

// %% [markdown]
// # Unit 9 - Inheritance Lesson
//
//
// [Runtime](https://replit.com/@dnchemtutors/Draw-Shape#src/main/java/Sphere.java)
//
// <img width="710" alt="Screenshot 2024-10-10 at 8 19 37 PM" src="https://github.com/user-attachments/assets/19506465-3705-4c33-9f19-b513562d9543">
//
// I noticed we had a method drawShape in our lesson. But...what if we actually DREW the the shapes

// %% [markdown]
// ## Key Notes/Summaries
//
// Here is a quick slideshow I made on units 1-8. I didn't have notes for unit 9 as I did the lesson.

// %% [markdown]
//   <style>
//     /* Carousel container */
//     .carousel {
//       width: 80%;
//       max-width: 600px;
//       margin: 0 auto;
//       overflow: hidden;
//       position: relative;
//       border: 2px solid #333;
//       border-radius: 10px;
//     }
//
//     /* Carousel slides wrapper */
//     .carousel-slides {
//       display: flex;
//       transition: transform 0.5s ease-in-out;
//     }
//
//     /* Each slide */
//     .carousel-slide {
//       min-width: 100%;
//       box-sizing: border-box;
//     }
//
//     /* Carousel images */
//     .carousel-slide img {
//       width: 100%;
//       display: block;
//       border-radius: 10px;
//     }
//
//     /* Navigation arrows */
//     .carousel-arrow {
//       position: absolute;
//       top: 50%;
//       transform: translateY(-50%);
//       background-color: rgba(0, 0, 0, 0.5);
//       color: white;
//       border: none;
//       padding: 10px;
//       cursor: pointer;
//       font-size: 20px;
//       border-radius: 50%;
//       z-index: 100;
//     }
//
//     .carousel-arrow:hover {
//       background-color: rgba(0, 0, 0, 0.7);
//     }
//
//     .prev {
//       left: 10px;
//     }
//
//     .next {
//       right: 10px;
//     }
//   </style>
// <body>
//
//   <div class="carousel">
//     <div class="carousel-slides" id="carousel-slides">
//       <!-- Slides will be dynamically inserted here -->
//     </div>
//     <!-- Arrow buttons -->
//     <button class="carousel-arrow prev" onclick="prevSlide()">&#10094;</button>
//     <button class="carousel-arrow next" onclick="nextSlide()">&#10095;</button>
//   </div>
//
//   <script>
//     const images = [
//       "https://github.com/user-attachments/assets/559cae43-5e09-4ac1-85b9-d28eb0ccf531",
//       "https://github.com/user-attachments/assets/ff3d2fba-0093-454e-bc5f-36da7d3130ac",
//       "https://github.com/user-attachments/assets/ba50f826-73af-411c-a42d-fe1da7e6caed",
//       "https://github.com/user-attachments/assets/11eb8ddb-5bb5-42d1-88f4-f8f4be2fa0e5",
//       "https://github.com/user-attachments/assets/307cd5d4-f543-4c59-bcfc-28954ab648a4",
//       "https://github.com/user-attachments/assets/8e6ed4c8-f3d2-4187-a998-be1a8e390123",
//       "https://github.com/user-attachments/assets/99769f15-4749-4702-8f32-64a44a4b89e0",
//       "https://github.com/user-attachments/assets/ff479c27-73a1-4828-9624-68329026568f"
//     ];
//
//     const carouselSlides = document.getElementById('carousel-slides');
//
//     // Dynamically add images to the carousel
//     images.forEach(image => {
//       const slide = document.createElement('div');
//       slide.classList.add('carousel-slide');
//       slide.innerHTML = `<img src="${image}" alt="Carousel Image">`;
//       carouselSlides.appendChild(slide);
//     });
//
//     const totalSlides = images.length;
//     let currentIndex = 0;
//
//     function showSlide(index) {
//       if (index >= totalSlides) {
//         currentIndex = 0;
//       } else if (index < 0) {
//         currentIndex = totalSlides - 1;
//       } else {
//         currentIndex = index;
//       }
//       carouselSlides.style.transform = `translateX(-${currentIndex * 100}%)`;
//     }
//
//     function nextSlide() {
//       showSlide(currentIndex + 1);
//     }
//
//     function prevSlide() {
//       showSlide(currentIndex - 1);
//     }
//   </script>
//
// </body>
