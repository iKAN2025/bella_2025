# %% [raw]
# ---
# layout: page
# title: About
# permalink: /aboutme/
# ---

# %% [markdown]
# <title>iKAN2025</title>
#   <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
#   <style>
#     .profile-pic {
#       display: block;
#       margin: 0 auto;
#       transition: transform 0.3s;
#     }
#
#     .profile-pic:hover {
#       transform: scale(1.1);
#     }
#
#     .tabs {
#       text-align: center;
#       margin: 20px 0;
#     }
#
#     .tab-button {
#       padding: 10px 20px;
#       margin: 5px;
#       border: 1px solid #ccc;
#       background-color: #f1f1f1;
#       cursor: pointer;
#     }
#
#     .tab-content {
#       display: none;
#       text-align: center;
#       margin-top: 20px;
#     }
#
#     canvas {
#       display: block;
#       margin: 0 auto;
#     }
#
#     .slider {
#         box-shadow: 0 10px 20px -5px rgba(0, 0, 0, 0.125);
#         height: 200px;
#         margin: auto;
#         overflow: hidden;
#         position: relative;
#         border-radius: 5px;
#     }
#
#     .slider::before,
#     .slider::after {
#         background: linear-gradient(to right, #121212 0%, rgba(255, 255, 255, 0) 100%);
#         content: "";
#         height: 200px;
#         position: absolute;
#         width: 200px;
#         z-index: 2;
#     }
#
#     .slider::after {
#         right: 0;
#         top: 0;
#         transform: rotateZ(180deg);
#     }
#
#     .slider::before {
#         left: 0;
#         top: 0;
#     }
#
#     .slider .slide-track {
#         display: flex;
#         animation: scroll 60s linear infinite;
#     }
#
#     .slider .slide {
#         flex: 0 0 auto;
#         width: auto;
#         height: 200px;
#         padding-left: 10px;
#         padding-right: 10px;
#     }
#
#     .slide img {
#         width: 100%;
#         height: 100%;
#         object-fit: cover;
#         border-radius: 5px;
#     }
#
#     @keyframes scroll {
#         0% {
#             transform: translateX(0);
#         }
#
#         100% {
#             transform: translateX(calc(-250px * 28));
#         }
#     }
#   </style>
# <body>
#
# <img src="https://github.com/iKAN2025.png" class="profile-pic mt-4" alt="Profile Picture">
#
# <div class="text-center">
#   <h2>iKAN2025</h2>
# </div>
#
#
# <h2> Favorite Movies <h2>
# <div class="slider">
#     <div class="slide-track" id="slide-track">
#         <!-- Images will be appended here via JavaScript -->
#     </div>
# </div>
#
# <script>
#
# const images = [
#     "https://github.com/user-attachments/assets/af8f5522-b185-46bd-87eb-a9b53247bd30",
#     "https://github.com/user-attachments/assets/9b59d07b-8aa4-4260-960f-8516383ef04f",
#     "https://github.com/user-attachments/assets/ffa3a749-f526-4c5a-89f9-baf18b1b54fb",
#     "https://github.com/user-attachments/assets/7701c498-683c-49d3-9826-756f9c93f1a8",
#     "https://github.com/user-attachments/assets/8e19a16b-443e-44dc-8c13-f4e7c1803b62",
#     "https://github.com/user-attachments/assets/908959d2-39a3-40ad-90a4-140290f8ccd0"
# ];
#
#     // Function to create image elements
#     function createImage(src) {
#         const img = document.createElement('img');
#         img.src = src;
#         img.height = 200;
#         img.style.objectFit = 'cover';
#         img.style.borderRadius = '5px';
#         return img;
#     }
#
#     // Function to add images to the track
#     function addImages() {
#         const track = document.getElementById('slide-track');
#         images.forEach(src => {
#             const slideDiv = document.createElement('div');
#             slideDiv.className = 'slide';
#             slideDiv.appendChild(createImage(src));
#             track.appendChild(slideDiv);
#         });
#     }
#
#     // Infinite loop to keep appending images
#     function loopImages() {
#         addImages(); // First load
#         setInterval(addImages, 100); // Re-add images
#     }
#
#     // Start appending images on page load
#     window.onload = loopImages;
#
#
# </script>
#
#
#
#
#
#
#
#
#
# <h2 style="color:blue;">Fun Facts About Me</h2>
# <div style="text-align: center;">
#   <select id="userQuestion" style="margin-bottom: 20px;">
#     <option value="default">Select a question</option>
#     <option value="color">What's your favorite color?</option>
#     <option value="icecream">What's your favorite ice cream flavor?</option>
#     <option value="hobby">What are your favorite hobbies?</option>
#   </select>
#   <button onclick="showAnswer()">See Answer</button>
#   <div id="response" style="margin-top: 20px;"></div>
# </div>
#
# <script>
#   function showAnswer() {
#     const question = document.getElementById("userQuestion").value;
#     let responseHTML = "";
#
#     if (question === "color") {
#       responseHTML = `
#         <p>My favorite color is blue! It's calming and reminds me of the ocean.</p>
#         <img src="{{ site.baseurl }}/images/blue_color.png" alt="Favorite Color: Blue" style="width: 200px; display: block; margin: 0 auto;">
#       `;
#     } else if (question === "icecream") {
#       responseHTML = `
#         <p>I'm a huge fan of chocolate chip cookie dough ice cream!</p>
#         <img src="{{ site.baseurl }}/images/icecream.png" alt="Favorite Ice Cream" style="width: 200px; display: block; margin: 0 auto;">
#       `;
#     } else if (question === "hobby") {
#       responseHTML = `
#         <p>In my free time, I love going biking and watching TV. These activities help me relax!</p>
#         <img src="{{ site.baseurl }}/images/biking.png" alt="Hobbies: Biking" style="width: 200px; display: block; margin: 0 auto;">
#       `;
#     } else {
#       responseHTML = "<p>Please select a question from the dropdown!</p>";
#     }
#
#     document.getElementById("response").innerHTML = responseHTML;
#   }
# </script>
#
#
#
#
#
# <h2 class="text-primary">Featured Projects</h2>
# <div class="tabs">
#   <button class="tab-button btn btn-primary text-white" onclick="showTab('wellness')">Wellness Tracker</button>
#   <button class="tab-button btn btn-primary text-white" onclick="showTab('fitness')">Fitness Tracker</button>
#   <button class="tab-button btn btn-primary text-white" onclick="showTab('instrument')">Instrument Tracker</button>
# </div>
#
# <div id="wellness" class="tab-content">
#   <div class="card mb-3">
#     <img class="card-img-top" src="{{ site.baseurl }}/images/wellness.png" alt="Wellness Tracker">
#     <div class="card-body">
#       <h5 class="card-title"><a href="https://github.com/jplip/self-care-front" class="text-dark">Wellness Tracker</a></h5>
#       <p class="card-text">A Full Stack Wellness Tracker</p>
#       <p><strong>Worked On:</strong> I worked on exercise, sleep, login, register, profile features. CRUD Operations, Frontend Api Layer</p>
#       <p><strong>Technologies:</strong> Python, Javascript, JWT, SQLAlchemy, Flask.</p>
#       <p><strong>Outcome:</strong> Enhanced user experience and engagement.</p>
#     </div>
#   </div>
# </div>
#
# <div id="fitness" class="tab-content">
#   <div class="card mb-3">
#     <img class="card-img-top" src="{{ site.baseurl }}/images/fitness.png" alt="Fitness App">
#     <div class="card-body">
#       <h5 class="card-title"><a href="https://github.com/jplip/frontTri2" class="text-dark">Fitness Tracker</a></h5>
#       <p class="card-text">A full-stack web application for fitness</p>
#       <p><strong>Worked On:</strong> I worked on exercise, sleep, login, register, profile features. CRUD Operations, Frontend Api Layer</p>
#       <p><strong>Technologies:</strong> Python, Javascript, JWT, SQLAlchemy, Flask.</p>
#       <p><strong>Outcome:</strong> Enhanced user experience and engagement.</p>
#     </div>
#   </div>
# </div>
#
# <div id="instrument" class="tab-content">
#   <div class="card mb-3">
#     <img class="card-img-top" src="{{ site.baseurl }}/images/musical.png" alt="Instrument Tracker">
#     <div class="card-body">
#       <h5 class="card-title"><a href="https://github.com/iKAN2025/" class="text-dark">Instrument Tracker</a></h5>
#       <p class="card-text">Tracks Instruments and Sorts Into Graphs</p>
#       <p><strong>Worked On:</strong> I worked on creating users and organizing data into graphs.</p>
#       <p><strong>Technologies:</strong> Python, Flask.</p>
#       <p><strong>Outcome:</strong> Enhanced user experience and engagement.</p>
#     </div>
#   </div>
# </div>
#
# <h2 class="text-primary">Some things I do in my free time are:</h2>
# <ul>
#   <li>Watch YouTube</li>
#   <li>Go biking</li>
#   <li>Watch TV</li>
# </ul>
#
# <h2 class="text-primary">Skills</h2>
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script> <!-- Bootstrap JS -->
# </body>

# %% [markdown]
# <canvas id="skillsChart"></canvas>
#
# <script>
#   function showTab(tabId) {
#     const tabs = document.querySelectorAll('.tab-content');
#     tabs.forEach(tab => tab.style.display = 'none');
#
#     const activeTab = document.getElementById(tabId);
#     if (activeTab) {
#       activeTab.style.display = 'block';
#     }
#   }
#
#   const ctx = document.getElementById('skillsChart').getContext('2d');
#   const skillsChart = new Chart(ctx, {
#     type: 'bar',
#     data: {
#       labels: ['JavaScript', 'Python', 'Flask', 'SQLAlchemy'],
#       datasets: [{
#         label: 'Skill Level',
#         data: [90, 80, 75, 70], // Example data
#         backgroundColor: 'rgba(54, 162, 235, 0.2)',
#         borderColor: 'rgba(54, 162, 235, 1)',
#         borderWidth: 1
#       }]
#     },
#     options: {
#       scales: {
#         y: {
#           beginAtZero: true
#         }
#       }
#     }
#   });
# </script>
# <script src="https://cdn.jsdelivr.net/npm/chart.js"></script> <!-- Chart.js Library -->

# %% [markdown]
# <h1 class="text-primary">About me</h1>
# <p>Hi, I'm iKAN2025, a student at Del Norte High School who is interested in computer science. I am passionate about full-stack development and machine learning. I love solving real-world problems through technology and enjoy collaborating with teams to build innovative solutions.</p>
#
# <h2 class="text-primary">Key Interests</h2>
# <ul>
#   <li><strong>Technology and Innovation</strong>: Leveraging technology to solve complex problems.</li>
#   <li><strong>Machine Learning and AI</strong>: Developing and implementing intelligent systems.</li>
#   <li><strong>Full Stack Development</strong>: Building comprehensive web applications from front-end to back-end.</li>
#   <li><strong>Team Collaboration</strong>: Working effectively within teams to achieve common goals.</li>
# </ul>

# %% [markdown]
# <script>
# const ctx = document.getElementById('skillsChart').getContext('2d');
#   const skillsChart = new Chart(ctx, {
#     type: 'bar',
#     data: {
#       labels: ['JavaScript', 'Python', 'Flask', 'SQLAlchemy'],
#       datasets: [{
#         label: 'Skill Level',
#         data: [90, 80, 75, 70], // Example data
#         backgroundColor: 'rgba(54, 162, 235, 0.2)',
#         borderColor: 'rgba(54, 162, 235, 1)',
#         borderWidth: 1
#       }]
#     },
#     options: {
#       scales: {
#         y: {
#           beginAtZero: true
#         }
#       }
#     }
#   });
# </script>
# <script src="https://cdn.jsdelivr.net/npm/chart.js"></script> <!-- Chart.js Library -->
