# %% [markdown]
# ---
# toc: false
# comments: true
# layout: post
# title: Night at the Museum Blog
# permalink: /nightatmuseum
# toc: true
# comments: true
# ---

# %% [markdown]
# Night at the Museum was a great experience for me! I was given the opportunity to explain my profile, the tools I used, and my new learning. Along with meeting with parents and students to show our project, I was able to discuss with others and learn about their projects.

# %% [markdown]
# ## Feedback
# We got a lot of great feedback on our project. For example, people said our website was well designed, but there could be more functions added in profile/backend. Here is a spreadsheet of [feedback](https://docs.google.com/spreadsheets/d/19MgrDRyOyzWlKFI8TtKIal0JfXHN8mjss4aTyITSok4/edit?gid=125967697#gid=125967697) we got :)

# %% [markdown]
# ![launch]({{site.baseurl}}/images/l.png)

# %% [markdown]
# ### Glows:
# - Good interaction with audience members and excellent presentation skills.
# - The website is very well designed and easy to operate.
# - Features like saving email, name, and password when logging in again work effectively.
# - Secure login page implemented well using Java and Python.
# - The system allows users to log in and retrieve saved data successfully.
# - The project was presented well by the team members (Trystan, Dylan, Bella, and Nikhil).
# - Overall experience is user-friendly and enjoyable.
#
# ### Grows:
# - Include the database (`.db`) file in `.gitignore` to avoid security risks.
# - Improve user interaction by clearing the email field after signing out.
# - Autosave feature is buggy; consider removing or improving it.
# - Update the CSS and front end to make it more visually appealing and align with the Nighthawk Pages style.
# - Allow users to edit their own accounts securely (e.g., logged-in users can edit their profiles and no one else’s).
# - Have the reset password on frontend, looks like trouble creating both accounts
# - Enable functionality for users to delete their accounts or change their passwords in the database.
# - Enhance the efficiency of the update page for a smoother user experience.

# %% [markdown]
# #  Reviewing Other Projects
#
# I reviewed projects from CSP and CSSE.
#
#
# - For CSP, in the first trimester, I noticed that the frontend had a lot of good design and creativity, but a lot of groups didn't start on the backend. For new projects, I saw frontend-backend work, but I felt a lot of groups lost their creativity.
#
# - For CSSE, I noticed a lot of improvement from the first n@tm. In the beginning, I saw that the games students built could have more interaction within the game itself, but the backgrounds were aesthetically appealing. But I can see a lot of improvement between first and second trimester.
#
#
#
# ![launch]({{site.baseurl}}/images/nmm.png)
# ![launch]({{site.baseurl}}/images/mmn.png)

# %% [markdown]
# # Other Projects (3D Animation, Art)
#
# - Here is a slideshow of projects outside CSA/CSP than I liked.

# %% [markdown]
#   <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
#   <style>
#     .profile-pic {
#       display: block;
#       margin: 0 auto;
#       transition: transform 0.3s;
#     }
#
#     .profile-pic:hover {
#       transform: scale(1.1);
#     }
#
#     .tabs {
#       text-align: center;
#       margin: 20px 0;
#     }
#
#     .tab-button {
#       padding: 10px 20px;
#       margin: 5px;
#       border: 1px solid #ccc;
#       background-color: #f1f1f1;
#       cursor: pointer;
#     }
#
#     .tab-content {
#       display: none;
#       text-align: center;
#       margin-top: 20px;
#     }
#
#     canvas {
#       display: block;
#       margin: 0 auto;
#     }
#
#     .slider {
#         box-shadow: 0 10px 20px -5px rgba(0, 0, 0, 0.125);
#         height: 200px;
#         margin: auto;
#         overflow: hidden;
#         position: relative;
#         border-radius: 5px;
#     }
#
#     .slider::before,
#     .slider::after {
#         background: linear-gradient(to right, #121212 0%, rgba(255, 255, 255, 0) 100%);
#         content: "";
#         height: 200px;
#         position: absolute;
#         width: 200px;
#         z-index: 2;
#     }
#
#     .slider::after {
#         right: 0;
#         top: 0;
#         transform: rotateZ(180deg);
#     }
#
#     .slider::before {
#         left: 0;
#         top: 0;
#     }
#
#     .slider .slide-track {
#         display: flex;
#         animation: scroll 60s linear infinite;
#     }
#
#     .slider .slide {
#         flex: 0 0 auto;
#         width: auto;
#         height: 200px;
#         padding-left: 10px;
#         padding-right: 10px;
#     }
#
#     .slide img {
#         width: 100%;
#         height: 100%;
#         object-fit: cover;
#         border-radius: 5px;
#     }
#
#     @keyframes scroll {
#         0% {
#             transform: translateX(0);
#         }
#
#         100% {
#             transform: translateX(calc(-250px * 28));
#         }
#     }
#   </style>
# <body>
#
#
#
#
# <div class="slider">
#     <div class="slide-track" id="slide-track">
#         <!-- Images will be appended here via JavaScript -->
#     </div>
# </div>
#
# <script>
#
# const images = [
#     "https://github.com/user-attachments/assets/ddf7838b-84be-4ab8-a677-b8e22ccbe6ce",
#     "https://github.com/user-attachments/assets/816666eb-6cf5-4b5c-9c60-b3c1d593b91e",
#     "https://github.com/user-attachments/assets/28928d7a-e7c5-44cf-abfa-ff955e66be13",
#     "https://github.com/user-attachments/assets/441a3653-b03c-437f-9ea4-a6b19bd8ad1a",
#     "https://github.com/user-attachments/assets/314bb0a6-53b6-4340-953e-629441553158",
# ];
#
#     // Function to create image elements
#     function createImage(src) {
#         const img = document.createElement('img');
#         img.src = src;
#         img.height = 200;
#         img.style.objectFit = 'cover';
#         img.style.borderRadius = '5px';
#         return img;
#     }
#
#     // Function to add images to the track
#     function addImages() {
#         const track = document.getElementById('slide-track');
#         images.forEach(src => {
#             const slideDiv = document.createElement('div');
#             slideDiv.className = 'slide';
#             slideDiv.appendChild(createImage(src));
#             track.appendChild(slideDiv);
#         });
#     }
#
#     // Infinite loop to keep appending images
#     function loopImages() {
#         addImages(); // First load
#         setInterval(addImages, 100); // Re-add images
#     }
#
#     // Start appending images on page load
#     window.onload = loopImages;
#
#
# </script>
