# %% [raw]
# ---
# layout: post
# title:  Tool Hacks
# description: These hacks are for tools that are used in the development process. Completing these hacks will help you to understand the tools better and are foundational for the course
# categories: [DevOps]
# permalink: /devops/hacks
# menu: nav/tools_setup.html
# toc: true
# comments: true
# ---

# %% [markdown]
# ## Tools Installation Hack
#
# Objective: Understand the basics of setting up a development environment and the tools required.
#
#
# ### Shell Commands
#
# - **Take note and describe the type of shell commands you are using through Terminal in this installation procedure.** This is specific to your machine.
#   - Examples: `wsl`, `cd`, `git`, `apt`, `brew`, etc.
#
# ### Version Control
#
# - **In the development process, developers use version control. Annotate in your notes what you have learned about version control during this setup process.**
#   - How are the files from GitHub placed on your local machine? How do you navigate to those files?
#   - How are the files updated in GitHub? How do you navigate to those files?
#   - How would you update your template of the `student_2025` repository? How would you make it more applicable to your specific course?
#
# ### Localhost vs. Deployed Server
#
# - **Put into words the difference between viewing GitHub Pages running on your localhost machine versus running on a deployed server.**
#   - What is the localhost URL for your project? Can anyone else see what you see?
#   - What is the GitHub Pages URL for your project? Can anyone else see what you see?
#
# ### DNS and GitHub Pages
#
# - **DNS is the address manager for the internet. Reflect on the following questions:**
#   - Is there a domain on your GitHub Pages?
#   - Is the URL for your GitHub Pages different from your neighbors' URLs? Did you change the URL? If so, when?
#
#
# #### Prepare for Pair Showcase (GitHub)
# By answering question in this section of hacks you will gain a deeper understanding of the tools and processes involved in setting up and managing a development environment, version control, and deploying a website.
#
# ---
#
# Prepare a 1-2 minute summary on the questions related to tools.
#
# ---

# %% [markdown]
# ### Shell Commands
#
# During the installation process, I utilized various shell commands in the Terminal:
#
# - **`cd`**: This command was used to navigate between directories, allowing me to move into project folders or specific directories where the installation or configuration files were located.
# - **`git`**: I used Git commands extensively for version control.
#   - `git clone` was employed to copy repositories from GitHub to my local machine.
#   - Other commands like `git commit` were used to save changes, `git push` to upload changes back to GitHub, and `git pull` to sync my local repository with the remote one.
# - **`brew`**: On macOS, I used Homebrew to install necessary software packages. For instance, installing Python or other dependencies needed for the project.
# - **`python`**: The `python --version` command helped verify that Python was installed correctly. I also used Python commands to run scripts and check for the correct functioning of installed packages.
#
# ### Version Control
#
# Version control was a key part of the setup process:
#
# - **Cloning Repositories**: I cloned repositories from GitHub to my local machine using the `git clone` command. This placed all the files in a directory on my computer, which I accessed using the `cd` command.
# - **Navigating and Updating Files**: After making changes to the files locally, I used `git add`, `git commit`, and `git push` to stage, commit, and push these changes back to GitHub. I navigated to these files using the Terminal.
# - **Updating the Portfolio Template**: To update the `portfolio_2025` repository, I would pull the latest changes, edit the files to reflect my course requirements, and push the updated version to my GitHub repository. For example, I added some of the blogs.
#
# ### Localhost vs. Deployed Server
#
# Understanding the difference between localhost and a deployed server is crucial:
#
# - **Localhost**: The localhost URL (`http://localhost:<port_number>`) allows me to view and test my project on my machine. This URL is not accessible to others; it’s used for development and testing purposes.
# - **Deployed Server (GitHub Pages)**: The deployed version of my project is accessible at a public URL provided by GitHub Pages, such as [https://ikan2025.github.io/student_2025/](https://ikan2025.github.io/student_2025/). Anyone with this link can view the site.
#
# ### DNS and GitHub Pages
#
# DNS (Domain Name System) plays a role in how my GitHub Pages site is accessed:
#
# - **Domain**: Currently, my GitHub Pages does not have a custom domain. The URL provided is based on my GitHub username and repository name.
# - **Unique URL**: My GitHub Pages URL is unique and differs from others due to the combination of my GitHub username and the repository name. I haven’t changed the URL, but I could set up a custom domain if needed.
#
# ### Tools Verification
#
# For verifying tools:
#
# - **Tool Installation**: I ensured that tools like Python, Git, Ruby, and others were installed correctly by running their version commands (e.g., `git --version`, `python --version`).
# - **Basic Command Execution**: I ran basic commands for each tool to check their functionality. This confirmed that the installations were successful and the tools were working as expected.
# - **Issue Resolution**: I documented any issues encountered during the setup and the steps taken to resolve them, ensuring a smooth development process.
#
# ### GitHub Usage with VSCode
#
# Using GitHub in conjunction with VSCode became an integral part of my workflow:
#
# - **Commit**: I made frequent commits to save changes locally, ensuring that my work was always up-to-date and backed up.
# - **Push and Pull**: Regularly pushing updates to GitHub and pulling changes from the remote repository helped keep my project synchronized across different environments.
# - **GitLens Extension**: The GitLens extension in VSCode provided a clear view of the commit history, showing who made changes and when. It also highlighted the contributors to the project, making collaboration easier.
#
# ### Summary for Pair Showcase
#
# For the Pair Showcase, I would summarize the following:
#
# - **Tools Verification**: I verified the installation and functionality of essential tools like Python, Git, and Ruby by executing version commands and running basic scripts. Any issues encountered were documented and resolved promptly.
# - **GitHub Usage**: I used GitHub with VSCode for version control, performing frequent commits, pushing updates, and pulling changes to keep the project in sync. The GitLens extension helped track the commit history and contributions, offering insights into the project’s development over time.
# """

# %% [markdown]
# ## Tool Play with JavaScript
#
# **Objective**: Use your tools installation to learn JavaScript, create dynamic web content, and understand that there are many ways to solve the same problem (coding styles).
#
# ### JavaScript Ideation
#
# Using ideas and hints from the Tool Play lesson, start the ideation process in Jupyter Notebooks to define your future `index.md` home page.
#
# Ideation in the course starts in Jupyter Notebooks. Follow these steps:
#
# 1. **Create an HTML File**: Start with an HTML file that includes a container element.
# 2. **Enhance with CSS**: Use CSS to style your HTML elements.
# 3. **Modify with JavaScript**: Use JavaScript to dynamically modify content within the HTML container.
#
# **Vocabulary Note**: Modifying an HTML container is often referred to as modifying the DOM (Document Object Model). The term "DOM" will be used frequently in the course and is associated with the "document." prefix used in commands like `document.createElement`.
#
# ### Update `index.md` Home Page
#
# Transition from ideation to designing your own home pages. As you work with your pair, you should learn similar coding styles, but your end product should be unique.
#
# 1. **Integrate JavaScript**: Incorporate your JavaScript code into your GitHub Pages project.
# 2. **Verify Display**: Ensure that the dynamic content is displayed correctly on both localhost and the deployed server.
# 3. **Document Challenges**: Blog about any challenges faced and how you overcame them.
#
# ### Prepare a 2-Minute Summary on Your `index.md`
#
# 1. **Demo the Pages**: Show the live pages on both localhost and the deployed server.
# 2. **Show the Code**: Walk through the JavaScript code that modifies the DOM.
# 3. **Jupyter Ideation Process**: Explain the ideation process documented in your Jupyter Notebooks.
# 4. **Coding Style Question**: Be prepared to answer the question, "How could you use another coding style to change your loop?" For example, if you used a `for` loop, explain how you could use `forEach` or another iteration method.
#
# By completing these "Hacks," you will gain a deeper understanding of the tools and processes involved in setting up and managing a development environment, verifying tool installations, and applying JavaScript to create dynamic web content.
#
# ---
#
# Prepare a 2-minute summary on your Home Page coding accomplishments.
#
# ---
